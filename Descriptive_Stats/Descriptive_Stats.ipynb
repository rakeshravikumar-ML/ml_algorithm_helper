# %% [markdown]
# # Step 1: Importing Required Libraries

# %% [markdown]
# ## Importing Required Libraries
#
# ### Breaking Down the Code:
#
# ```python
# # avoiding harmless warnings
# import warnings
# warnings.filterwarnings('ignore')
#
#
# # Required libraries
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# avoiding harmless warnings
import warnings
warnings.filterwarnings('ignore')


# Required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Step 2: Creating a Sample Dataset

# %% [markdown]
# ## Creating a Sample Dataset
#
# ### Breaking Down the Code:
#
# ```python
# # dummy data point
# dps = np.array([1,2,3,4,5,5,5,6,7,9])
# print(dps, type(dps))
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# dummy data point
dps = np.array([1,2,3,4,5,5,5,6,7,9])
print(dps, type(dps))
# Out:
# [1 2 3 4 5 5 5 6 7 9] <class 'numpy.ndarray'>

# %% [markdown]
# # Step 3: Computing Mean, Median, and Mode

# %% [markdown]
# ## Computing Mean, Median, and Mode
#
# ### Breaking Down the Code:
#
# ```python
# # mean
# print(np.mean(dps))
#
# # median
# print(np.median(dps))
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# mean
print(np.mean(dps))

# median
print(np.median(dps))
# Out:
# 4.7
# 5.0

# %% [markdown]
# # Step 4: Visualizing Data Distributions - Histograms & KDE

# %% [markdown]
# ## Visualizing Data Distributions - Histograms & KDE
#
# ### Breaking Down the Code:
#
# ```python
# # dummy data point with outliers
# dps_o = np.array([1,2,3,4,5,5,5,6,7,9,38,40])
# print(dps, type(dps_o))
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# dummy data point with outliers
dps_o = np.array([1,2,3,4,5,5,5,6,7,9,38,40])
print(dps, type(dps_o))
# Out:
# [1 2 3 4 5 5 5 6 7 9] <class 'numpy.ndarray'>

# %% [markdown]
# # Step 5: Checking for Missing Values

# %% [markdown]
# ## Checking for Missing Values
#
# ### Breaking Down the Code:
#
# ```python
# # mean
# print(np.mean(dps_o))
#
# # median
# print(np.median(dps_o))
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# mean
print(np.mean(dps_o))

# median
print(np.median(dps_o))
# Out:
# 10.416666666666666
# 5.0

# %% [markdown]
# # Step 6: Measuring Variance & Standard Deviation

# %% [markdown]
# ## Measuring Variance & Standard Deviation
#
# ### Breaking Down the Code:
#
# ```python
# # creating data frame
# lst = [1, 46, 29, 84, 12, 14, 103, 61, 90, 30, 110]
# data = pd.DataFrame(lst, columns=['values'])
# data
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# creating data frame
lst = [1, 46, 29, 84, 12, 14, 103, 61, 90, 30, 110]
data = pd.DataFrame(lst, columns=['values'])
data
# Out:
#     values
# 0        1
# 1       46
# 2       29
# 3       84
# 4       12
# 5       14
# 6      103
# 7       61
# 8       90
# 9       30
# 10     110

# %% [markdown]
# # Step 7: Understanding Skewness & Kurtosis

# %% [markdown]
# ## Understanding Skewness & Kurtosis
#
# ### Breaking Down the Code:
#
# ```python
# # to get help from documentation
# ? sns.boxplot
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# to get help from documentation
? sns.boxplot

# %% [markdown]
# # Step 8: Computing Percentiles & Quartiles

# %% [markdown]
# ## Computing Percentiles & Quartiles
#
# ### Breaking Down the Code:
#
# ```python
# # box plot
# sns.boxplot(data['values'], orient='h')
# plt.show()
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# box plot
sns.boxplot(data['values'], orient='h')
plt.show()

# %% [markdown]
# # Step 9: Interquartile Range (IQR) & Boxplots

# %% [markdown]
# ## Interquartile Range (IQR) & Boxplots
#
# ### Breaking Down the Code:
#
# ```python
# # five number summary
# print('Min:', data['values'].min())
# print('Q1:', data['values'].quantile(0.25))
# print('Q2:', data['values'].median())
# print('Q3:', data['values'].quantile(0.75))
# print('Max:', data['values'].max())
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# five number summary
print('Min:', data['values'].min())
print('Q1:', data['values'].quantile(0.25))
print('Q2:', data['values'].median())
print('Q3:', data['values'].quantile(0.75))
print('Max:', data['values'].max())
# Out:
# Min: 1
# Q1: 21.5
# Q2: 46.0
# Q3: 87.0
# Max: 110

# %% [markdown]
# # Step 10: Detecting Outliers Using Z-Scores

# %% [markdown]
# ## Detecting Outliers Using Z-Scores
#
# ### Breaking Down the Code:
#
# ```python
# # summary function
# data['values'].describe()
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# summary function
data['values'].describe()
# Out:
# count     11.000000
# mean      52.727273
# std       38.989975
# min        1.000000
# 25%       21.500000
# 50%       46.000000
# 75%       87.000000
# max      110.000000
# Name: values, dtype: float64

# %% [markdown]
# # Step 11: Winsorization - Handling Extreme Outliers

# %% [markdown]
# ## Winsorization - Handling Extreme Outliers
#
# ### Breaking Down the Code:
#
# ```python
# # creating data frame with outliers
# lst_o = [1, 46, 29, 84, 12, 14, 103, 61, 90, 30, 110, 600, 650]
# data_o = pd.DataFrame(lst_o, columns=['values'])
# data_o
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# creating data frame with outliers
lst_o = [1, 46, 29, 84, 12, 14, 103, 61, 90, 30, 110, 600, 650]
data_o = pd.DataFrame(lst_o, columns=['values'])
data_o
# Out:
#     values
# 0        1
# 1       46
# 2       29
# 3       84
# 4       12
# 5       14
# 6      103
# 7       61
# 8       90
# 9       30
# 10     110
# 11     600
# 12     650

# %% [markdown]
# # Step 12: Confidence Intervals for Mean Estimation

# %% [markdown]
# ## Confidence Intervals for Mean Estimation
#
# ### Breaking Down the Code:
#
# ```python
# # box plot
# sns.boxplot(data_o['values'], orient='h')
# plt.show()
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# box plot
sns.boxplot(data_o['values'], orient='h')
plt.show()

# %% [markdown]
# # Step 13: Normality Testing - Shapiro-Wilk & Kolmogorov-Smirnov

# %% [markdown]
# ## Normality Testing - Shapiro-Wilk & Kolmogorov-Smirnov
#
# ### Breaking Down the Code:
#
# ```python
# # list of dataset in seaborn library
# sns.get_dataset_names()
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# list of dataset in seaborn library
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# # Step 14: Comparing Distributions - Log Transformation

# %% [markdown]
# ## Comparing Distributions - Log Transformation
#
# ### Breaking Down the Code:
#
# ```python
# # sample data set from seaborn library
# penguin_data = sns.load_dataset('penguins')
# penguin_data.head()
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# sample data set from seaborn library
penguin_data = sns.load_dataset('penguins')
penguin_data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# # Step 15: Data Scaling & Standardization

# %% [markdown]
# ## Data Scaling & Standardization
#
# ### Breaking Down the Code:
#
# ```python
# # stats summary of quantitative data
# penguin_data.describe()
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# stats summary of quantitative data
penguin_data.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# # Step 16: Comparing Standardized & Non-Standardized Distributions

# %% [markdown]
# ## Comparing Standardized & Non-Standardized Distributions
#
# ### Breaking Down the Code:
#
# ```python
# # boxplot
# for cols in penguin_data:
#     if penguin_data[cols].dtype != 'O':
#         sns.boxplot(penguin_data[cols], orient='h')
#         plt.show()
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# boxplot
for cols in penguin_data:
    if penguin_data[cols].dtype != 'O':
        sns.boxplot(penguin_data[cols], orient='h')
        plt.show()

# %% [markdown]
# # Step 17: Visualizing Correlation Among Features

# %% [markdown]
# ## Visualizing Correlation Among Features
#
# ### Breaking Down the Code:
#
# ```python
# # distinct classes of a column
# penguin_data['species'].unique()
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# distinct classes of a column
penguin_data['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %% [markdown]
# # Step 18: Comparing Descriptive Stats Across Multiple Groups

# %% [markdown]
# ## Comparing Descriptive Stats Across Multiple Groups
#
# ### Breaking Down the Code:
#
# ```python
# # value counts of classes in a column
# penguin_data['species'].value_counts()
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# value counts of classes in a column
penguin_data['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# # Step 19: Exploring Trends in Descriptive Statistics

# %% [markdown]
# ## Exploring Trends in Descriptive Statistics
#
# ### Breaking Down the Code:
#
# ```python
# # proportion of values classes in columns
# round(penguin_data['species'].value_counts(normalize=True)*100, 2)
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# proportion of values classes in columns
round(penguin_data['species'].value_counts(normalize=True)*100, 2)
# Out:
# species
# Adelie       44.19
# Gentoo       36.05
# Chinstrap    19.77
# Name: proportion, dtype: float64

# %% [markdown]
# # Step 20: Building an Automated Summary Report

# %% [markdown]
# ## Building an Automated Summary Report
#
# ### Breaking Down the Code:
#
# ```python
# # most repeated classe
# print(penguin_data['species'].mode())
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# most repeated classe
print(penguin_data['species'].mode())
# Out:
# 0    Adelie
# Name: species, dtype: object

# %% [markdown]
# # Step 21: Applying Descriptive Statistics in Real-World Scenarios

# %% [markdown]
# ## Applying Descriptive Statistics in Real-World Scenarios
#
# ### Breaking Down the Code:
#
# ```python
# # plot
# ax = sns.countplot(x=penguin_data['species'], color='purple')
# ax.bar_label(ax.containers[0])
# plt.show()
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# plot
ax = sns.countplot(x=penguin_data['species'], color='purple')
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# # Step 22: Final Thoughts & Best Practices in Statistical Analysis

# %% [markdown]
# ## Final Thoughts & Best Practices in Statistical Analysis
#
# ### Breaking Down the Code:
#
# ```python
# # Home work
#
#     # 1. find the count plot for all categorical data on penguin data set using for loop
#     # 2. use "tips" dataset and find the numerical summary for the data
#     # 3. for "tips" dataset find the insights for categorical columns
#     # 4. check if there is outliers in the "tips" data columns
# ```
#
# - **Line-by-line breakdown:**
#   - Explanation for each function and parameter.

# %%
# Home work

    # 1. find the count plot for all categorical data on penguin data set using for loop
    # 2. use "tips" dataset and find the numerical summary for the data
    # 3. for "tips" dataset find the insights for categorical columns
    # 4. check if there is outliers in the "tips" data columns
